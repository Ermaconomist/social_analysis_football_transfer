# %%
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("final_clean.csv")

# %%
df
# Out:
#       Unnamed: 0  Unnamed: 0.1 Season                 Name Transfer Sum  \
# 0              0             0  20/21        Arthur Cabral  4,40 Mio. €
# 1              1             1  20/21            Kaly Sene  4,00 Mio. €
# 2              2             2  20/21        Edon Zhegrova  3,00 Mio. €
# 3              3             3  20/21        Andrea Padula   450 Tsd. €
# 4              4             4  20/21        Heinz Lindner   ablösefrei
# ...          ...           ...    ...                  ...          ...
# 4023        4364          4364  11/12  Mickaël Facchinetti        Leihe
# 4024        4365          4365  11/12       Palmiro Di Dio            -
# 4025        4366          4366  11/12       Patrice Feussi            -
# 4026        4367          4367  11/12          Rijat Shala            -
# 4027        4368          4368  11/12       Fabio Liverani            -
#
#                  From  FromCountry FromLanguage FromLanguageFamily  \
# 0           Palmeiras       Brazil   Portuguese            Romance
# 1        Juventus U19        Italy      Italian            Romance
# 2           KRC Genk       Belgium       French            Romance
# 3         FC Wil 1900  Switzerland       German           Germanic
# 4     Wehen Wiesbaden      Germany       German           Germanic
# ...               ...          ...          ...                ...
# 4023        FC Lugano  Switzerland      Italian            Romance
# 4024        FC Lugano  Switzerland      Italian            Romance
# 4025        FC Lugano  Switzerland      Italian            Romance
# 4026        FC Lugano  Switzerland      Italian            Romance
# 4027        FC Lugano  Switzerland      Italian            Romance
#
#                  To     ToCountry    ToLanguage ToLanguageFamily
# 0          FC Basel   Switzerland        German         Germanic
# 1          FC Basel   Switzerland        German         Germanic
# 2          FC Basel   Switzerland        German         Germanic
# 3          FC Basel   Switzerland        German         Germanic
# 4          FC Basel   Switzerland        German         Germanic
# ...             ...           ...           ...              ...
# 4023  Chievo Verona         Italy       Italian          Romance
# 4024  FC Lugano U21   Switzerland       Italian          Romance
# 4025     Vereinslos    Vereinslos    Vereinslos       Vereinslos
# 4026     Vereinslos    Vereinslos    Vereinslos       Vereinslos
# 4027   Karriereende  Karriereende  Karriereende     Karriereende
#
# [4028 rows x 13 columns]

# %%
df_nodes = df[['From','To']]
df_nodes
# Out:
#                  From             To
# 0           Palmeiras       FC Basel
# 1        Juventus U19       FC Basel
# 2           KRC Genk        FC Basel
# 3         FC Wil 1900       FC Basel
# 4     Wehen Wiesbaden       FC Basel
# ...               ...            ...
# 4023        FC Lugano  Chievo Verona
# 4024        FC Lugano  FC Lugano U21
# 4025        FC Lugano     Vereinslos
# 4026        FC Lugano     Vereinslos
# 4027        FC Lugano   Karriereende
#
# [4028 rows x 2 columns]

# %%
ids = []
clubs = []
for i , club in enumerate(pd.concat([df['To'],df['From']]).unique()):
    ids.append(i)
    clubs.append(club)
    
df_club_id_from = pd.DataFrame({'id_From': ids, 'From':clubs})    
df_club_id_to = pd.DataFrame({'id_To': ids, 'To':clubs})
df_club_id_from
# Out:
#      id_From          From
# 0          0      FC Basel
# 1          1    Hertha BSC
# 2          2   Montpellier
# 3          3    Bröndby IF
# 4          4    CD Leganés
# ..       ...           ...
# 895      895     ES Zarzis
# 896      896       Brescia
# 897      897  Pergolettese
# 898      898    Giulianova
# 899      899        Casale
#
# [900 rows x 2 columns]

# %%
df_club_id_to
# Out:
#      id_To            To
# 0        0      FC Basel
# 1        1    Hertha BSC
# 2        2   Montpellier
# 3        3    Bröndby IF
# 4        4    CD Leganés
# ..     ...           ...
# 895    895     ES Zarzis
# 896    896       Brescia
# 897    897  Pergolettese
# 898    898    Giulianova
# 899    899        Casale
#
# [900 rows x 2 columns]

# %%
df_temp = pd.merge(df, df_club_id_from , how = 'inner', on='From')

# %%
df_temp = pd.merge(df_temp, df_club_id_to , how = 'inner', on='To')

# %%
df_temp
# Out:
#       Unnamed: 0  Unnamed: 0.1 Season            Name Transfer Sum  \
# 0              0             0  20/21   Arthur Cabral  4,40 Mio. €
# 1              1             1  20/21       Kaly Sene  4,00 Mio. €
# 2              2             2  20/21   Edon Zhegrova  3,00 Mio. €
# 3             57            57  18/19   Edon Zhegrova        Leihe
# 4              3             3  20/21   Andrea Padula   450 Tsd. €
# ...          ...           ...    ...             ...          ...
# 4023        3113          3113  12/13  Gaël N'Lundulu   ablösefrei
# 4024        3117          3117  12/13     Thierno Bah            ?
# 4025        3118          3118  12/13   Nélson Borges            ?
# 4026        3120          3120  12/13    Aadil Assana    Leih-Ende
# 4027        3145          3145  11/12    Rodrigo Tosi   ablösefrei
#
#                    From  FromCountry FromLanguage FromLanguageFamily  \
# 0             Palmeiras       Brazil   Portuguese            Romance
# 1          Juventus U19        Italy      Italian            Romance
# 2             KRC Genk       Belgium       French            Romance
# 3             KRC Genk       Belgium       French            Romance
# 4           FC Wil 1900  Switzerland       German           Germanic
# ...                 ...          ...          ...                ...
# 4023  FC Lausanne-Sport  Switzerland       French            Romance
# 4024  FC Lausanne-Sport  Switzerland       French            Romance
# 4025  FC Lausanne-Sport  Switzerland       French            Romance
# 4026  FC Lausanne-Sport  Switzerland       French            Romance
# 4027  FC Lausanne-Sport  Switzerland       French            Romance
#
#                  To     ToCountry     ToLanguage ToLanguageFamily  id_From  \
# 0          FC Basel   Switzerland         German         Germanic      613
# 1          FC Basel   Switzerland         German         Germanic      187
# 2          FC Basel   Switzerland         German         Germanic       52
# 3          FC Basel   Switzerland         German         Germanic       52
# 4          FC Basel   Switzerland         German         Germanic       21
# ...             ...           ...            ...              ...      ...
# 4023  Chern. Burgas      Bulgaria      Bulgarian           Slavic      455
# 4024      Al-Taawon  Saudi Arabia         Arabic          Semitic      455
# 4025      FC Prilly   Switzerland         French          Romance      455
# 4026      AS Monaco        France         French          Romance      455
# 4027        Tractor          Iran  Persian Farsi     Indo-Iranian      455
#
#       id_To
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# ...     ...
# 4023    488
# 4024    489
# 4025    490
# 4026    491
# 4027    492
#
# [4028 rows x 15 columns]

# %%
df_id = df_temp[['id_From','id_To']]
df_id
# Out:
#       id_From  id_To
# 0         613      0
# 1         187      0
# 2          52      0
# 3          52      0
# 4          21      0
# ...       ...    ...
# 4023      455    488
# 4024      455    489
# 4025      455    490
# 4026      455    491
# 4027      455    492
#
# [4028 rows x 2 columns]

# %%
df_id.to_string("final.txt", encoding="utf-8-sig", header = None, index = None )
df_txt = df_id

# %%
G = nx.Graph()
G = nx.DiGraph()
G = nx.MultiGraph()
G = nx.MultiDiGraph()

# %%
network =  nx.DiGraph()

# %%
g = nx.from_pandas_edgelist(df_temp, 
                            source = 'From',
                            target = 'To',
                            edge_attr = None,
                            create_using = nx.Graph())

# %%
df_temp20 = df.loc[df['Season'] == '20/21']
df_temp19 = df.loc[df['Season'] == '19/20']
df_temp18 = df.loc[df['Season'] == '18/19']
df_temp17 = df.loc[df['Season'] == '17/18']
df_temp16 = df.loc[df['Season'] == '16/17']
df_temp15 = df.loc[df['Season'] == '15/16']
df_temp14 = df.loc[df['Season'] == '14/15']
df_temp13 = df.loc[df['Season'] == '13/14']
df_temp12 = df.loc[df['Season'] == '12/13']
df_temp11 = df.loc[df['Season'] == '11/12']
df_temp20
# Out:
#       Unnamed: 0  Unnamed: 0.1 Season             Name Transfer Sum  \
# 0              0             0  20/21    Arthur Cabral  4,40 Mio. €
# 1              1             1  20/21        Kaly Sene  4,00 Mio. €
# 2              2             2  20/21    Edon Zhegrova  3,00 Mio. €
# 3              3             3  20/21    Andrea Padula   450 Tsd. €
# 4              4             4  20/21    Heinz Lindner   ablösefrei
# ...          ...           ...    ...              ...          ...
# 3708        4004          4004  20/21   Carlo Manicone        Leihe
# 3709        4006          4006  20/21        Eloge Yao            -
# 3710        4007          4007  20/21  Daniel Pavlovic            -
# 3711        4008          4008  20/21    Joel Untersee            -
# 3712        4009          4009  20/21   Fulvio Sulmoni            -
#
#                  From  FromCountry FromLanguage FromLanguageFamily  \
# 0           Palmeiras       Brazil   Portuguese            Romance
# 1        Juventus U19        Italy      Italian            Romance
# 2           KRC Genk       Belgium       French            Romance
# 3         FC Wil 1900  Switzerland       German           Germanic
# 4     Wehen Wiesbaden      Germany       German           Germanic
# ...               ...          ...          ...                ...
# 3708        FC Lugano  Switzerland      Italian            Romance
# 3709        FC Lugano  Switzerland      Italian            Romance
# 3710        FC Lugano  Switzerland      Italian            Romance
# 3711        FC Lugano  Switzerland      Italian            Romance
# 3712        FC Lugano  Switzerland      Italian            Romance
#
#                 To     ToCountry    ToLanguage ToLanguageFamily
# 0         FC Basel   Switzerland        German         Germanic
# 1         FC Basel   Switzerland        German         Germanic
# 2         FC Basel   Switzerland        German         Germanic
# 3         FC Basel   Switzerland        German         Germanic
# 4         FC Basel   Switzerland        German         Germanic
# ...            ...           ...           ...              ...
# 3708      Grosseto         Italy       Italian          Romance
# 3709    Vereinslos    Vereinslos    Vereinslos       Vereinslos
# 3710    Vereinslos    Vereinslos    Vereinslos       Vereinslos
# 3711    Vereinslos    Vereinslos    Vereinslos       Vereinslos
# 3712  Karriereende  Karriereende  Karriereende     Karriereende
#
# [309 rows x 13 columns]

# %%
listyear = [
    'df_temp20',
    'df_temp19',
    'df_temp18',
    'df_temp17',
    'df_temp16',
    'df_temp15',
    'df_temp14',
    'df_temp13',
    'df_temp12',
    'df_temp11',
    'df_temp20',
    'df_temp19',
    'df_temp18',
    'df_temp17',
    'df_temp16',
    'df_temp15',
    'df_temp14',
    'df_temp13',
    'df_temp12',
    'df_temp11']

# %% [markdown]
# #### Plotting Networt to show which Teams deliver Players to which language in the Season 20/21
# * Saving the plot as a .pdf-File (example: fig.savefig('network20.pdf'))

# %%
fig = plt.figure(figsize=(10, 10)) 
g = nx.from_pandas_edgelist(df_temp20, 
                            source = 'From',
                            target = 'To',
                            edge_attr = 'FromLanguageFamily',
                            create_using = nx.DiGraph())
nx.draw(g, with_labels = True) 
plt.axis('equal') 
plt.show()
fig.savefig('network20.pdf')

# %%
fig = plt.figure(figsize=(20, 20)) 

g = nx.from_pandas_edgelist(df_temp, 
                            source = 'FromLanguageFamily',
                            target = 'ToLanguageFamily',
                            edge_attr = 'FromLanguageFamily',
                            create_using = nx.MultiDiGraph())
node_color = [20000.0 * g.degree(v) for v in g]
nx.draw(g, node_color=node_color, edge_color='black', with_labels = True, font_size=20) 
plt.axis('equal') 
plt.show()
fig.savefig('networkTestalle.pdf')

# %%
fig = plt.figure(figsize=(20, 20)) 

g = nx.from_pandas_edgelist(df_temp, 
                            source = 'FromLanguageFamily',
                            target = 'ToLanguageFamily',
                            edge_attr = 'FromLanguageFamily',
                            create_using = nx.MultiDiGraph())

edge = df_temp20['FromLanguageFamily']
pos = nx.spring_layout(g)
nx.draw(g, with_labels=True, node_color='skyblue', edge_cmap=plt.cm.Blues, pos=pos)
edge_labels = nx.get_edge_attributes(g,'edge')
nx.draw_networkx_edge_labels(g,pos,edge_labels=formatted_edge_labels,font_color='red')
plt.show()
fig.savefig('networkedgelabel.pdf')

# %%
fig = plt.figure(figsize=(10, 10)) 
g = nx.from_pandas_edgelist(df_tempZ20, 
                            source = 'FromLanguageFamily',
                            target = 'To',
                            edge_attr = 'ToLanguageFamily',
                            create_using = nx.MultiDiGraph())
nx.draw(g, with_labels = True) 
plt.axis('scaled') 
plt.show()
fig.savefig('networkTestZ20.pdf')

# %%
fig = plt.figure(figsize=(10, 10)) 
q = nx.from_pandas_edgelist(df_temp, 
                            source = 'From',
                            target = 'To',
                            edge_attr = 'ToLanguageFamily',
                            create_using = nx.Graph())
nx.draw(g, with_labels = True) 
plt.axis('equal') 
plt.show()
fig.savefig('network_all.pdf')

# %%
sorted(betCent, key=betCent.get, reverse=True)[:5]
# Out:
# ['Romance', 'Germanic', 'Vereinslos', 'Karriereende', 'FC Lugano']

# %%
pos = nx.spring_layout(q)

betCent = nx.betweenness_centrality(q, normalized=True, endpoints=True)
node_color = [20000.0 * q.degree(v) for v in q]
node_size =  [v * 10000 for v in betCent.values()]
plot = plt.figure(figsize = (20,20))
nx.draw_networkx(q, pos=pos, with_labels=True,
                 font_size=2,
                 node_color=node_color,
                 node_size=node_size,
                 create_using = nx.MultiDiGraph())
plt.axis('off')
plot.savefig('network_all2.pdf')
# Out:
# C:\Users\ginoc\AppData\Roaming\Python\Python37\site-packages\matplotlib\backends\_backend_pdf_ps.py:62: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0.0, flags=ft2font.LOAD_NO_HINTING)
# C:\Users\ginoc\AppData\Roaming\Python\Python37\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\ginoc\AppData\Roaming\Python\Python37\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
 print(nx.info(g))
# Out:
# Name:
# Type: Graph
# Number of nodes: 904
# Number of edges: 1700
# Average degree:   3.7611
