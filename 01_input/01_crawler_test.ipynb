# %%
import itertools
import requests
from bs4 import BeautifulSoup as soup
import re
import pandas as pd
import sqlalchemy

# %%
url = "https://www.transfermarkt.com/raiffeisen-super-league/transfers/wettbewerb/C1?saison_id=2020"

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/68.0.3440.84 Safari/537.36',
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
}

# %%
html_page = requests.get(url, headers = headers).text

# %%
soup_page = soup(html_page)

# %%
clubs = soup_page.find_all(class_="box")
club2 = clubs[4].find(class_="table-header").text

club2
# Out:
# 'BSC Young Boys'

# %%
clubs = soup_page.find_all(class_="box")
club3 = clubs[4].find_all("th")

titles = []

for titel in club3:
    titles.append(titel.text)
    
#club3
titles
# Out:
# ['In',
#  'Age',
#  'Nat.',
#  'Position',
#  'Pos',
#  'Market value',
#  'Left',
#  'Fee',
#  'Out',
#  'Age',
#  'Nat.',
#  'Position',
#  'Pos',
#  'Market value',
#  'Joined',
#  'Fee']

# %%
clubs = soup_page.find_all(class_="box")
club4 = clubs[4].find_all(class_ ="responsive-table")
club4
# Out:
# [<div class="responsive-table">
#  <table>
#  <thead>
#  <tr>
#  <th class="spieler-transfer-cell">In</th>
#  <th class="zentriert alter-transfer-cell">Age</th>
#  <th class="zentriert nat-transfer-cell">Nat.</th>
#  <th class="pos-transfer-cell">Position</th>
#  <th class="kurzpos-transfer-cell zentriert">Pos</th>
#  <th class="rechts mw-transfer-cell">Market value</th>
#  <th class="verein-transfer-cell" colspan="2">Left</th>
#  <th class="rechts abloese-transfer-cell">Fee</th>
#  </tr>
#  </thead>
#  <tbody>
#  <tr>
#  <td><div class="di nowrap"><span class="hide-for-small"><a class="spielprofil_tooltip" href="/silvan-hefti/profil/spieler/237666" id="237666" title="Silvan Hefti">Silvan Hefti</a></span></div><div class="di nowrap"><span class="show-for-small"><a class="spielprofil_tooltip" href="/silvan-hefti/profil/spieler/237666" id="237666" title="Silvan Hefti">S. Hefti</a></span></div></td>
#  <td class="zentriert alter-transfer-cell">22</td>
# ...

# %%
clubs = soup_page.find_all(class_="box")
club4 = clubs[4].find_all(class_ ="responsive-table")



tables = club4[0].findChildren('table')



# This will get the first (and only) table. Your page may have more.

my_table = tables[0]

# You can find children with multiple tags by passing a list of strings
rows = my_table.findChildren(['th', 'tr'])

tabletti = []

for row in rows:
    cells = row.findChildren('td')
    for cell in cells:
        tabletti.append(cell.text)

# %%
soup_page.find_all(class_="box")





article = soup_page.find('div', class_="responsive-table")

invalid_tags = ['b', 'i', 'u', 'br', 'a']
for match in soup.find_all(invalid_tags):
     match.unwrap()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-197-4a044be9c1c4> in <module>
#       8
#       9 invalid_tags = ['b', 'i', 'u', 'br', 'a']
# ---> 10 for match in soup.find_all(invalid_tags):
#      11      match.unwrap()
#
# ~/anaconda3/envs/ams/lib/python3.8/site-packages/bs4/element.py in find_all(self, name, attrs, recursive, text, limit, **kwargs)
#    1783         :rtype: bs4.element.ResultSet
#    1784         """
# -> 1785         generator = self.descendants
#    1786         if not recursive:
#    1787             generator = self.children
#
# AttributeError: 'list' object has no attribute 'descendants'

# %%
temp
# Out:
# [[<tr>
#   <th class="spieler-transfer-cell">In</th>
#   <th class="zentriert alter-transfer-cell">Age</th>
#   <th class="zentriert nat-transfer-cell">Nat.</th>
#   <th class="pos-transfer-cell">Position</th>
#   <th class="kurzpos-transfer-cell zentriert">Pos</th>
#   <th class="rechts mw-transfer-cell">Market value</th>
#   <th class="verein-transfer-cell" colspan="2">Left</th>
#   <th class="rechts abloese-transfer-cell">Fee</th>
#   </tr>,
#   <th class="spieler-transfer-cell">In</th>,
#   <th class="zentriert alter-transfer-cell">Age</th>,
#   <th class="zentriert nat-transfer-cell">Nat.</th>,
#   <th class="pos-transfer-cell">Position</th>,
#   <th class="kurzpos-transfer-cell zentriert">Pos</th>,
#   <th class="rechts mw-transfer-cell">Market value</th>,
#   <th class="verein-transfer-cell" colspan="2">Left</th>,
#   <th class="rechts abloese-transfer-cell">Fee</th>,
#   <tr>
# ...

# %%
clubs = soup_page.find_all(class_="box")
club5 = clubs[5].find_all(class_ ="responsive-table")

for result in club5:  
    try
    print(name = result.find('div', attrs={"class": "spielprofil_tooltip"}).text)
    continue
# Out:
#   File "<ipython-input-163-ea174b9afef9>", line 5
#     try
#        ^
# SyntaxError: invalid syntax

# %%
club5
# Out:
# [<div class="responsive-table">
#  <table>
#  <thead>
#  <tr>
#  <th class="spieler-transfer-cell">In</th>
#  <th class="zentriert alter-transfer-cell">Age</th>
#  <th class="zentriert nat-transfer-cell">Nat.</th>
#  <th class="pos-transfer-cell">Position</th>
#  <th class="kurzpos-transfer-cell zentriert">Pos</th>
#  <th class="rechts mw-transfer-cell">Market value</th>
#  <th class="verein-transfer-cell" colspan="2">Left</th>
#  <th class="rechts abloese-transfer-cell">Fee</th>
#  </tr>
#  </thead>
#  <tbody>
#  <tr>
#  <td><div class="di nowrap"><span class="hide-for-small"><a class="spielprofil_tooltip" href="/lukas-watkowiak/profil/spieler/196791" id="196791" title="Lukas Watkowiak">Lukas Watkowiak</a></span></div><div class="di nowrap"><span class="show-for-small"><a class="spielprofil_tooltip" href="/lukas-watkowiak/profil/spieler/196791" id="196791" title="Lukas Watkowiak">L. Watkowiak</a></span></div></td>
#  <td class="zentriert alter-transfer-cell">24</td>
# ...

# %%
club_table_in  = clubs_cleaned[0].find_all(class_ ="responsive-table")[0]
club_table_in  = club_table_in.findChildren(['tr'])

cont = []

for item in club_table_in:
    cont.append(item.text)

for row in cont:
    print(row.split())
    print(len(row))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-0a6b734d3a17> in <module>
# ----> 1 club_table_in  = clubs_cleaned[0].find_all(class_ ="responsive-table")[0]
#       2 club_table_in  = club_table_in.findChildren(['tr'])
#       3
#       4 cont = []
#       5
#
# NameError: name 'clubs_cleaned' is not defined

# %%
#tables = soup_page.find_all(class_="responsive-table")

#for table in tables:
    
#    table_rows = table.find_all('tr')
    
#    global df
#    df = []
    
#    for tr in table_rows:
#        td = tr.find_all('td')
#        row = [i.text for i in td]
#        df.append(row)
        
#df

# %%
def extract_tables(soup_object):
    
    df = []
    
    tables = soup_page.find_all(class_="responsive-table")
    
    global table_head
    table_head = []
    table_head = tables[1].find('th')
    
    table_rows = []
    for table in tables:
        table_rows += table.find_all('tr')
        
    for tr in table_rows:
        td = tr.find_all('td')
        row = [i.text for i in td]
        df.append(row)
        
    return df

# %%
extract_tables(soup_page)

# %%
df = pd.DataFrame(data=all_rows,columns=headings)

# %%
tables = soup_page.find_all(class_="responsive-table")
    
for table in tables:
    table_rows += table.find_all('tr')
    
table_rows

# %%
for table, heading in zip(gdp_table_data[1].find_all("table"), headings):
    # Get headers of table i.e., Rank, Country, GDP.
    t_headers = []
    for th in table.find_all("th"):
        # remove any newlines and extra spaces from left and right
        t_headers.append(th.text.replace('\n', ' ').strip())
    # Get all the rows of table
    table_data = []
    for tr in table.tbody.find_all("tr"): # find all tr's from table's tbody
        t_row = {}
        # Each table row is stored in the form of
        # t_row = {'Rank': '', 'Country/Territory': '', 'GDP(US$million)': ''}

        # find all td's(3) in tr and zip it with t_header
        for td, th in zip(tr.find_all("td"), t_headers): 
            t_row[th] = td.text.replace('\n', '').strip()
        table_data.append(t_row)

    # Put the data for the table with his heading.
    data[heading] = table_data

print(data)
